# %% [markdown]
# ### Number of clicks prediction
# ---

# %%
import pandas as pd
import numpy as np
import requests
from io import StringIO

import matplotlib.pyplot as plt
import time
import pickle
from pandas.plotting import scatter_matrix

# %% [markdown]
# #### 1- EDA

# %%
def loading_data(file_url):
    """
    Reading data from a given url
    
    inputs:
    ------
    url : link to the data
    returns
    -----:
    data : data frame  
    """
    
    file_id = file_url.split('/')[-2]
    dwn_url='https://drive.google.com/uc?export=download&id=' + file_id
    url = requests.get(dwn_url).text
    csv_raw = StringIO(url)
    df = pd.read_csv(csv_raw)
    
    
    return df

# %%
# Let's load the training data

# %%
hotel_url = 'https://drive.google.com/file/d/1c85h1hzgzLvAeYSh-EVpY6Gz3dYLsd6R/view?usp=sharing'
hotel_data = loading_data(hotel_url )

# %%
#hotel_data = hotel_data.sample(100)

# %%
# first we will have a quick look at the data head and tail
hotel_data.head()
# Out:
#        hotel_id   city_id  content_score  n_images  distance_to_center  \
# 0  9.767406e+10  134520.0           70.0       2.0              1199.0
# 1  9.768889e+10  133876.0           67.0       3.0             12585.0
# 2  9.811544e+10  133732.0           39.0       3.0             23491.0
# 3  9.824279e+10   43772.0           59.0       8.0              3291.0
# 4  9.833438e+10   50532.0           66.0       1.0               288.0
#
#    avg_rating  stars  n_reviews  avg_rank  avg_price  avg_saving_percent  \
# 0        77.0    4.0      861.0    17.550      81.64                18.0
# 1        90.0    4.0     4371.0    17.383     189.38                28.0
# 2        83.0    3.0     1005.0    16.438      57.63                27.0
# 3        73.0    2.0     3084.0     7.000      72.16                 2.0
# 4        80.0    0.0      603.0    12.564     173.25                 0.0
#
#    n_clicks
# 0         0
# 1         4
# 2        44
# 3         4
# 4        10

# %%
# we see that we have only numerical predictors

# %%
hotel_data.tail()
# Out:
#             hotel_id  city_id  content_score  n_images  distance_to_center  \
# 396482  1.277185e+11      NaN            NaN       NaN                 NaN
# 396483  6.841541e+09      NaN            NaN       NaN                 NaN
# 396484  8.649506e+10      NaN            NaN       NaN                 NaN
# 396485  1.293587e+11      NaN            NaN       NaN                 NaN
# 396486  1.609336e+10      NaN            NaN       NaN                 NaN
#
#         avg_rating  stars  n_reviews  avg_rank  avg_price  avg_saving_percent  \
# 396482         NaN    NaN        NaN    17.333     103.07                 0.0
# 396483         NaN    NaN        NaN    12.000      44.00                 0.0
# 396484         NaN    NaN        NaN     6.400      42.78                29.0
# 396485         NaN    NaN        NaN    18.143      96.23                36.0
# 396486         NaN    NaN        NaN    16.833      65.69                 5.0
#
#         n_clicks
# 396482         0
# 396483         0
# 396484         4
# 396485         4
# 396486         4

# %%
# We can see right a way that our data has Nan in it which indicate we will need some prepocessing and cleaning

# %%
# let's get a quick description of the dat set 

hotel_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396487 entries, 0 to 396486
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   hotel_id            396487 non-null  float64
#  1   city_id             395979 non-null  float64
#  2   content_score       395979 non-null  float64
#  3   n_images            395978 non-null  float64
#  4   distance_to_center  395958 non-null  float64
#  5   avg_rating          286089 non-null  float64
#  6   stars               395925 non-null  float64
#  7   n_reviews           395958 non-null  float64
#  8   avg_rank            396487 non-null  float64
#  9   avg_price           396317 non-null  float64
#  10  avg_saving_percent  396317 non-null  float64
#  11  n_clicks            396487 non-null  int64
# dtypes: float64(11), int64(1)
# memory usage: 36.3 MB

# %% [markdown]
# > We have 12 predictors, alll of them are float except the n_clicks which is integer
# > The data contains 396478 row. From the comparision of the counts, it appears that `avg_rating` has the maximum number of NaNs.

# %%
# Now let's have a look at the statistics of values
hotel_data.describe()
# Out:
#            hotel_id        city_id  content_score      n_images  \
# count  3.964870e+05  395979.000000  395979.000000  3.959780e+05
# mean   1.326304e+11  149193.465376      50.992795  2.593212e+02
# std    1.033722e+11  219189.285044      11.563444  1.731682e+04
# min    1.557962e+08       2.000000       7.000000 -1.000000e+00
# 25%    4.062255e+10   32014.000000      45.000000  0.000000e+00
# 50%    1.087280e+11   55122.000000      53.000000  1.000000e+00
# 75%    2.281935e+11  137464.000000      59.000000  2.000000e+00
# max    3.237114e+11  878736.000000      81.000000  2.393911e+06
#
#        distance_to_center     avg_rating          stars      n_reviews  \
# count        3.959580e+05  286089.000000  395925.000000  395958.000000
# mean         1.634383e+04      81.616525       1.159659     913.667419
# std          2.752200e+05       6.025140       1.619713    2432.494160
# min          0.000000e+00      34.000000       0.000000       0.000000
# 25%          5.440000e+02      79.000000       0.000000       0.000000
# 50%          1.516000e+03      83.000000       0.000000     189.000000
# 75%          4.163000e+03      86.000000       3.000000     777.000000
# max          1.834155e+07      97.000000       5.000000  283089.000000
#
#             avg_rank      avg_price  avg_saving_percent       n_clicks
# count  396487.000000  396317.000000       396317.000000  396487.000000
# mean       14.694502     109.332048            7.179601      13.781980
# std         5.604578     148.198851           13.081529     123.572896
# min         1.000000       4.000000            0.000000       0.000000
# 25%        11.091000      51.050000            0.000000       0.000000
# 50%        15.000000      77.650000            0.000000       0.000000
# 75%        18.375000     120.930000           10.000000       2.000000
# max       100.000000    8000.000000           99.000000   13742.000000

# %% [markdown]
#  > There are a couple of interesting observations:
#  - Content score ranging from 7 to 71 with a mean of 50.99
#  - We have some negative n_images which has to be removed
#  - Median avg_rating is 83.0 but median stars is 0.
#  - We have a median of189 for n_reviews
#  - The avg_price ranges from 4 to 8000 and the avg_saving ranges from 0 to 99%
#  - Hotels have avg n_clicks of 13.78

# %%
# Now let's look at a histogram for the data

hotel_data.hist(bins = 50, figsize=(10,15))
plt.show()

# %%
# Let's calculate Pearson's correlation to see if there is linear relationship between variables
corr_hotel = hotel_data.corr()
corr_hotel ['n_clicks'].sort_values(ascending = False)
# Out:
# n_clicks              1.000000
# n_reviews             0.215561
# avg_saving_percent    0.133875
# stars                 0.130860
# content_score         0.095450
# avg_price             0.015331
# avg_rating            0.005212
# n_images              0.002912
# distance_to_center   -0.004724
# city_id              -0.042874
# avg_rank             -0.081410
# hotel_id             -0.095660
# Name: n_clicks, dtype: float64

# %%
# now let's see how the numerical variables are correlated, we will drop city_id since it's categorical variable and hotel_id 
# because it's just an identifier
numerical_vars = ['content_score','n_images','distance_to_center','avg_rating','stars','n_reviews','avg_rank','avg_price','avg_saving_percent',
'n_clicks']

# %%
scatter_matrix(hotel_data[numerical_vars],figsize = (16,12));

# %% [markdown]
# > Both correlations and scatter matrix indicate that there is no single variable that has a string linear correlation with out target.

# %%
## Now le't look at features one by one

# %%
#1. hote_id : this column will be dropped

# %%
original_size = len(hotel_data
                   )
original_size
# Out:
# 396487

# %%
# 2 content score
hotel_data[['content_score']].describe()
# Out:
#        content_score
# count  395979.000000
# mean       50.992795
# std        11.563444
# min         7.000000
# 25%        45.000000
# 50%        53.000000
# 75%        59.000000
# max        81.000000

# %%
hotel_data[hotel_data['content_score'].isnull()]
# Out:
#             hotel_id  city_id  content_score  n_images  distance_to_center  \
# 34115   1.817005e+11      NaN            NaN       NaN                 NaN
# 34116   3.682004e+09      NaN            NaN       NaN                 NaN
# 34117   3.149413e+11      NaN            NaN       NaN                 NaN
# 34118   1.361512e+11      NaN            NaN       NaN                 NaN
# 34119   1.599323e+11      NaN            NaN       NaN                 NaN
# ...              ...      ...            ...       ...                 ...
# 396482  1.277185e+11      NaN            NaN       NaN                 NaN
# 396483  6.841541e+09      NaN            NaN       NaN                 NaN
# 396484  8.649506e+10      NaN            NaN       NaN                 NaN
# 396485  1.293587e+11      NaN            NaN       NaN                 NaN
# 396486  1.609336e+10      NaN            NaN       NaN                 NaN
#
#         avg_rating  stars  n_reviews  avg_rank  avg_price  avg_saving_percent  \
# 34115          NaN    NaN        NaN     7.882     136.48                 0.0
# 34116          NaN    NaN        NaN    16.987      72.79                 0.0
# 34117          NaN    NaN        NaN    11.000      79.03                 0.0
# 34118          NaN    NaN        NaN     1.000     375.00                37.0
# 34119          NaN    NaN        NaN     9.500     268.95                19.0
# ...            ...    ...        ...       ...        ...                 ...
# 396482         NaN    NaN        NaN    17.333     103.07                 0.0
# 396483         NaN    NaN        NaN    12.000      44.00                 0.0
# 396484         NaN    NaN        NaN     6.400      42.78                29.0
# 396485         NaN    NaN        NaN    18.143      96.23                36.0
# 396486         NaN    NaN        NaN    16.833      65.69                 5.0
#
#         n_clicks
# 34115        390
# 34116         24
# 34117          0
# 34118          4
# 34119          0
# ...          ...
# 396482         0
# 396483         0
# 396484         4
# 396485         4
# 396486         4
#
# [508 rows x 12 columns]

# %% [markdown]
# > We have 508 rows that has not only content_score as Nan but also n_images,distance_to_center, avg_rating, stars, and n_reviews

# %%
hotel_data = hotel_data[hotel_data['content_score'].notnull()]
len(hotel_data)
# Out:
# 395979

# %%
# 3 n_images
hotel_data[['n_images']].describe()
# Out:
#            n_images
# count  3.959780e+05
# mean   2.593212e+02
# std    1.731682e+04
# min   -1.000000e+00
# 25%    0.000000e+00
# 50%    1.000000e+00
# 75%    2.000000e+00
# max    2.393911e+06

# %% [markdown]
# > We have some negative n_images here we need to remove. Let's first check how many of these we have

# %%
hotel_data[hotel_data['n_images'] < 0]
# Out:
#             hotel_id   city_id  content_score  n_images  distance_to_center  \
# 309     2.310027e+11   40880.0           31.0      -1.0               864.0
# 911     2.390626e+11   43538.0           31.0      -1.0              3428.0
# 930     1.334373e+11   46306.0           32.0      -1.0               992.0
# 958     3.297190e+10    9668.0           37.0      -1.0               169.0
# 1185    2.425277e+11  146322.0           31.0      -1.0              2779.0
# ...              ...       ...            ...       ...                 ...
# 395627  2.247640e+11  193284.0           30.0      -1.0             10044.0
# 395997  1.998287e+11  137512.0           30.0      -1.0              5352.0
# 396212  1.531907e+11   55218.0            9.0      -1.0                 0.0
# 396406  2.128680e+11   50126.0            8.0      -1.0            331041.0
# 396429  2.192444e+11   26822.0           31.0      -1.0              3387.0
#
#         avg_rating  stars  n_reviews  avg_rank  avg_price  avg_saving_percent  \
# 309            NaN    0.0        0.0    16.000      72.00                 0.0
# 911            NaN    0.0        0.0    25.000      77.36                 0.0
# 930            NaN    0.0        0.0    10.000     201.51                 1.0
# 958            NaN    0.0        0.0    24.000     112.60                 0.0
# 1185           NaN    0.0        0.0    24.000     240.00                 0.0
# ...            ...    ...        ...       ...        ...                 ...
# 395627         NaN    0.0        0.0    14.000      94.88                 0.0
# 395997         NaN    0.0        0.0    24.000      50.80                 0.0
# 396212         NaN    0.0        0.0     8.596      46.46                 0.0
# 396406         NaN    0.0        0.0    19.000     183.08                 0.0
# 396429         NaN    0.0        0.0    14.000     369.50                 0.0
#
#         n_clicks
# 309            0
# 911            0
# 930            0
# 958            0
# 1185           0
# ...          ...
# 395627         0
# 395997         0
# 396212         0
# 396406         0
# 396429         0
#
# [3361 rows x 12 columns]

# %% [markdown]
# > 3361 rows, we notice that avg_rating for those rows is also NAN, so we will go agead and remove them.

# %%
hotel_data = hotel_data[hotel_data['n_images'] >= 0]

# %%
len(hotel_data)
# Out:
# 392617

# %%
# 4 content score
hotel_data[['distance_to_center']].describe()
# Out:
#        distance_to_center
# count        3.925970e+05
# mean         1.619290e+04
# std          2.736377e+05
# min          0.000000e+00
# 25%          5.470000e+02
# 50%          1.519000e+03
# 75%          4.162000e+03
# max          1.834155e+07

# %% [markdown]
# > No negative values here

# %%
hotel_data[hotel_data['distance_to_center'].isnull()]
# Out:
#             hotel_id   city_id  content_score  n_images  distance_to_center  \
# 30553   1.522385e+11   43532.0           23.0       0.0                 NaN
# 39281   5.983448e+10   46946.0           34.0       9.0                 NaN
# 75932   5.958532e+10  648742.0           19.0       1.0                 NaN
# 90914   2.670061e+09  833300.0           35.0       3.0                 NaN
# 108175  5.974874e+10   48872.0           36.0       2.0                 NaN
# 137342  6.000239e+10   48800.0           18.0       0.0                 NaN
# 168171  5.919428e+10   49648.0           20.0       0.0                 NaN
# 186157  5.983479e+10   49192.0           19.0       0.0                 NaN
# 186604  1.543787e+09   43538.0           33.0       4.0                 NaN
# 196679  5.955871e+10   48954.0           23.0       0.0                 NaN
# 197444  5.965329e+10   48900.0           23.0       0.0                 NaN
# 221832  6.001205e+10   48772.0           21.0       2.0                 NaN
# 240215  6.000613e+10   48916.0           21.0       0.0                 NaN
# 258690  1.259713e+11  109406.0           31.0       0.0                 NaN
# 271926  5.912656e+10   48236.0           29.0       1.0                 NaN
# 279662  3.335869e+10   64602.0           33.0       2.0                 NaN
# 297297  1.526787e+11   41144.0           37.0       0.0                 NaN
# 313229  6.010059e+10  131850.0           40.0       0.0                 NaN
# 321809  5.911970e+10   48322.0           19.0       0.0                 NaN
# 329228  5.977684e+10   48742.0           23.0       0.0                 NaN
#
#         avg_rating  stars  n_reviews  avg_rank  avg_price  avg_saving_percent  \
# 30553          NaN    NaN        NaN    22.000      81.22                 1.0
# 39281          NaN    NaN        NaN    20.333      46.58                 0.0
# 75932          NaN    NaN        NaN     7.200      39.63                 0.0
# 90914          NaN    NaN        NaN     8.500     101.08                44.0
# 108175         NaN    NaN        NaN    15.667      93.89                 0.0
# 137342         NaN    NaN        NaN    11.500      50.00                 0.0
# 168171         NaN    NaN        NaN    16.600      49.73                 0.0
# 186157         NaN    NaN        NaN    23.000      52.80                 0.0
# 186604         NaN    NaN        NaN    13.510     147.59                31.0
# 196679         NaN    NaN        NaN     9.278      93.54                 0.0
# 197444         NaN    NaN        NaN    18.000      51.36                 0.0
# 221832         NaN    NaN        NaN    17.379     148.49                 0.0
# 240215         NaN    NaN        NaN    17.750     175.04                 0.0
# 258690         NaN    NaN        NaN     3.000      57.49                15.0
# 271926         NaN    NaN        NaN    25.000     166.56                 0.0
# 279662         NaN    NaN        NaN    14.400     109.14                21.0
# 297297         NaN    NaN        NaN     3.000      84.86                 6.0
# 313229         NaN    NaN        NaN     1.000      43.19                 2.0
# 321809         NaN    NaN        NaN    16.857      55.60                11.0
# 329228         NaN    NaN        NaN    16.273     145.33                 0.0
#
#         n_clicks
# 30553          0
# 39281          4
# 75932          2
# 90914          0
# 108175         0
# 137342         0
# 168171         2
# 186157         0
# 186604        18
# 196679         0
# 197444         0
# 221832         0
# 240215         0
# 258690         0
# 271926         0
# 279662         0
# 297297         0
# 313229         2
# 321809         0
# 329228         2

# %% [markdown]
# > Again, only 21 rows that can be safely reomved

# %%
hotel_data = hotel_data[hotel_data['distance_to_center'].notnull()]

# %%
# 5 avg_rating
hotel_data[['avg_rating']].describe()
# Out:
#           avg_rating
# count  285854.000000
# mean       81.614695
# std         6.026569
# min        34.000000
# 25%        79.000000
# 50%        83.000000
# 75%        86.000000
# max        97.000000

# %% [markdown]
# > No negative values here

# %%
hotel_data[hotel_data['avg_rating'].isnull()]
# Out:
#             hotel_id   city_id  content_score  n_images  distance_to_center  \
# 9       9.902959e+10  208612.0           48.0       1.0              1795.0
# 26      1.004976e+11   54398.0           52.0       1.0              1013.0
# 74      1.115944e+11   61992.0           45.0       0.0               144.0
# 81      1.181972e+11   56480.0           49.0       0.0             10417.0
# 93      1.191401e+11   27532.0           46.0       0.0              1321.0
# ...              ...       ...            ...       ...                 ...
# 396467  2.285687e+11  137370.0           41.0       0.0              2129.0
# 396468  2.285979e+11  131846.0           42.0       0.0              6877.0
# 396469  2.288169e+11  878186.0           48.0       1.0               469.0
# 396471  2.290205e+11   31408.0           70.0       1.0              1424.0
# 396473  2.293708e+11  133338.0           36.0       1.0                 0.0
#
#         avg_rating  stars  n_reviews  avg_rank  avg_price  avg_saving_percent  \
# 9              NaN    0.0        0.0    19.000      21.38                 0.0
# 26             NaN    0.0        0.0    20.500      56.00                 0.0
# 74             NaN    0.0        0.0    19.000      82.26                 0.0
# 81             NaN    0.0        0.0    10.500     175.80                 0.0
# 93             NaN    0.0        0.0    13.000      60.83                 0.0
# ...            ...    ...        ...       ...        ...                 ...
# 396467         NaN    0.0        0.0    11.727      56.07                 0.0
# 396468         NaN    0.0        0.0     9.059      69.15                 0.0
# 396469         NaN    0.0        0.0    21.000      78.86                 0.0
# 396471         NaN    0.0        0.0    16.211      16.11                 0.0
# 396473         NaN    0.0        0.0    20.387      36.13                 0.0
#
#         n_clicks
# 9              0
# 26             0
# 74             0
# 81             0
# 93             0
# ...          ...
# 396467         0
# 396468         0
# 396469         0
# 396471         4
# 396473         0
#
# [106743 rows x 12 columns]

# %% [markdown]
# > we have 19,323 rows with NaN in avg rating. Instead of removing these rows, we will replace Nan with median

# %%
median_avg_rating = hotel_data['avg_rating'].median()

# %%
hotel_data['avg_rating'] = hotel_data['avg_rating'].fillna(median_avg_rating)

# %%
# 6 stars
hotel_data[['stars']].describe()
# Out:
#                stars
# count  392564.000000
# mean        1.169425
# std         1.622986
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         3.000000
# max         5.000000

# %% [markdown]
# > No negative values

# %%
hotel_data[hotel_data['stars'].isnull()]
# Out:
#             hotel_id   city_id  content_score  n_images  distance_to_center  \
# 7188    9.581946e+09   47290.0           48.0       0.0              1995.0
# 7558    2.496446e+09  863642.0           56.0       0.0              1883.0
# 20524   7.789558e+09   49660.0           50.0       1.0              2936.0
# 28720   8.276947e+09   49728.0           49.0       0.0              1504.0
# 37289   9.112159e+09   48884.0           46.0       0.0              2160.0
# 37837   8.214174e+09   49784.0           40.0       0.0               331.0
# 53660   3.507828e+09   31590.0           48.0       2.0              2639.0
# 56492   9.580077e+09   47290.0           51.0       0.0               166.0
# 57893   3.519697e+09  656352.0           45.0       0.0              1873.0
# 63147   7.789247e+09   49660.0           49.0       0.0               614.0
# 64235   2.726822e+09   31080.0           48.0       1.0              4879.0
# 64574   8.225856e+09   49776.0           47.0       0.0              5260.0
# 65380   7.924918e+09   49928.0           57.0       1.0               936.0
# 76909   8.495797e+09   49632.0           43.0       0.0               238.0
# 81958   8.333178e+09   49710.0           45.0       0.0               259.0
# 112750  3.561722e+09   31556.0           48.0       0.0              4391.0
# 112933  3.596863e+09   27534.0           58.0       0.0              2738.0
# 113340  8.577262e+09   49596.0           48.0       0.0              2871.0
# 132509  8.562309e+09   49598.0           41.0       0.0                53.0
# 157608  3.688048e+09  122978.0           57.0       0.0               828.0
# 173025  3.776398e+09  132210.0           50.0       1.0              1118.0
# 188788  8.309969e+09   49722.0           48.0       1.0              1372.0
# 188791  8.680690e+09   49536.0           49.0       0.0               162.0
# 208083  8.558414e+09   49598.0           51.0       0.0                55.0
# 214332  8.243613e+09   49758.0           54.0       0.0              1111.0
# 232265  8.335671e+09   49710.0           49.0       0.0              2147.0
# 234039  3.923004e+09  107868.0           50.0       0.0               387.0
# 234068  8.373833e+09   49676.0           57.0       3.0                48.0
# 235919  9.059822e+09   48916.0           59.0       5.0              1488.0
# 249320  9.056395e+09   48916.0           47.0       0.0               264.0
# 265549  8.180684e+09   49804.0           48.0       0.0                30.0
# 292305  3.006483e+09   27588.0           44.0       0.0               289.0
# 361328  8.430843e+09   49650.0           52.0       0.0               313.0
#
#         avg_rating  stars  n_reviews  avg_rank  avg_price  avg_saving_percent  \
# 7188          83.0    NaN        0.0     7.677      90.42                 0.0
# 7558          83.0    NaN      147.0    12.727      87.12                17.0
# 20524         83.0    NaN        0.0    14.250      47.11                 0.0
# 28720         82.0    NaN       81.0    16.100      36.56                 0.0
# 37289         83.0    NaN        0.0    20.077      97.04                 0.0
# 37837         83.0    NaN        0.0     7.000      38.40                 0.0
# 53660         81.0    NaN      102.0    18.831      94.42                 1.0
# 56492         83.0    NaN        0.0     7.000      72.97                 0.0
# 57893         83.0    NaN        0.0     7.000      40.00                 0.0
# 63147         83.0    NaN        0.0    11.750      59.97                 0.0
# 64235         83.0    NaN        0.0     9.500     113.58                 0.0
# 64574         83.0    NaN        0.0     7.000      52.00                 0.0
# 65380         82.0    NaN       60.0     6.000      53.69                 0.0
# 76909         84.0    NaN      120.0    21.077      83.15                 0.0
# 81958         83.0    NaN        0.0     8.500      58.80                 0.0
# 112750        83.0    NaN        0.0    22.375      87.71                 0.0
# 112933        83.0    NaN        0.0    24.500     490.72                 0.0
# 113340        83.0    NaN      114.0    23.333     101.73                 0.0
# 132509        83.0    NaN        0.0    17.018      67.01                 0.0
# 157608        73.0    NaN      141.0    22.000      62.40                 0.0
# 173025        83.0    NaN        0.0    12.200     183.12                 0.0
# 188788        83.0    NaN        0.0    12.000      35.97                 0.0
# 188791        83.0    NaN        0.0    15.667      54.40                 0.0
# 208083        83.0    NaN        0.0    14.000      45.60                 0.0
# 214332        85.0    NaN       99.0    16.000      59.88                 0.0
# 232265        80.0    NaN      132.0     7.667      47.14                 0.0
# 234039        83.0    NaN      210.0     9.407      10.80                 0.0
# 234068        85.0    NaN      153.0    20.722      79.55                11.0
# 235919        84.0    NaN      123.0    14.000      71.20                 0.0
# 249320        86.0    NaN       81.0    18.000      52.72                 0.0
# 265549        83.0    NaN       72.0    15.600     109.78                 0.0
# 292305        76.0    NaN       75.0    18.539      76.43                 0.0
# 361328        85.0    NaN       87.0    10.000     135.96                 1.0
#
#         n_clicks
# 7188           6
# 7558           2
# 20524          0
# 28720          0
# 37289          0
# 37837          0
# 53660          6
# 56492          0
# 57893          0
# 63147          0
# 64235          2
# 64574          0
# 65380          0
# 76909          0
# 81958          2
# 112750         0
# 112933         0
# 113340         0
# 132509         2
# 157608         0
# 173025         0
# 188788         0
# 188791         0
# 208083         0
# 214332         0
# 232265         4
# 234039       340
# 234068         0
# 235919         0
# 249320         0
# 265549         2
# 292305         0
# 361328         0

# %% [markdown]
# > Only 8 rows that can be safely removed

# %%
hotel_data = hotel_data[hotel_data['stars'].notnull()]

# %%
# 7 avg_rating
hotel_data[['n_reviews']].describe()
# Out:
#            n_reviews
# count  392564.000000
# mean      921.502726
# std      2441.518357
# min         0.000000
# 25%         0.000000
# 50%       192.000000
# 75%       789.000000
# max    283089.000000

# %% [markdown]
# > No negative values here

# %%
hotel_data[hotel_data['n_reviews'].isnull()]
# Out:
# Empty DataFrame
# Columns: [hotel_id, city_id, content_score, n_images, distance_to_center, avg_rating, stars, n_reviews, avg_rank, avg_price, avg_saving_percent, n_clicks]
# Index: []

# %% [markdown]
# > We don't have Nans here

# %%
# 8 avg_rank
hotel_data[['avg_rank']].describe()
# Out:
#             avg_rank
# count  392564.000000
# mean       14.677311
# std         5.594652
# min         1.000000
# 25%        11.074750
# 50%        15.000000
# 75%        18.333000
# max       100.000000

# %% [markdown]
# > No ngative values

# %%
hotel_data[hotel_data['avg_rank'].isnull()]
# Out:
# Empty DataFrame
# Columns: [hotel_id, city_id, content_score, n_images, distance_to_center, avg_rating, stars, n_reviews, avg_rank, avg_price, avg_saving_percent, n_clicks]
# Index: []

# %% [markdown]
# > We don't have Nans here

# %%
# 9 avg_price
hotel_data[['avg_price']].describe()
# Out:
#            avg_price
# count  392411.000000
# mean      108.920245
# std       146.944074
# min         4.000000
# 25%        51.020000
# 50%        77.590000
# 75%       120.640000
# max      8000.000000

# %% [markdown]
# > No negative values here.

# %%
hotel_data[hotel_data['avg_price'].isnull()]
# Out:
#             hotel_id   city_id  content_score  n_images  distance_to_center  \
# 1016    4.191063e+10    7696.0           54.0       2.0              2883.0
# 6487    3.863003e+09  138846.0           59.0       3.0               912.0
# 8321    1.225554e+11  192284.0           52.0       0.0               273.0
# 12298   1.545662e+11   27126.0           47.0       0.0              1977.0
# 17758   1.203430e+11  140508.0           47.0       0.0             14832.0
# ...              ...       ...            ...       ...                 ...
# 388350  1.532225e+11   38928.0           44.0       0.0               318.0
# 388546  2.118243e+11   54438.0           42.0       1.0              5730.0
# 388939  2.249208e+11   30600.0           47.0       0.0              5461.0
# 394115  3.176726e+11   63440.0           44.0       0.0              1611.0
# 395421  2.189300e+11   54244.0           23.0       0.0                 0.0
#
#         avg_rating  stars  n_reviews  avg_rank  avg_price  avg_saving_percent  \
# 1016          83.0    0.0     2625.0       1.0        NaN                 NaN
# 6487          83.0    0.0       90.0       1.0        NaN                 NaN
# 8321          80.0    0.0       66.0      12.0        NaN                 NaN
# 12298         83.0    0.0        0.0      13.0        NaN                 NaN
# 17758         83.0    0.0        0.0       1.0        NaN                 NaN
# ...            ...    ...        ...       ...        ...                 ...
# 388350        83.0    0.0        0.0      18.0        NaN                 NaN
# 388546        85.0    0.0      255.0       1.0        NaN                 NaN
# 388939        83.0    0.0        0.0       1.0        NaN                 NaN
# 394115        83.0    0.0        0.0       1.0        NaN                 NaN
# 395421        83.0    0.0        0.0      23.0        NaN                 NaN
#
#         n_clicks
# 1016           0
# 6487           0
# 8321           0
# 12298          0
# 17758          0
# ...          ...
# 388350         0
# 388546         0
# 388939         0
# 394115         0
# 395421         0
#
# [153 rows x 12 columns]

# %% [markdown]
# > We have 50 rows, we can see that in the same raws we have Nan in avg_saving_percent, we can go ahead and remove those

# %%
hotel_data = hotel_data[hotel_data['avg_price'].notnull()]

# %%
len(hotel_data)
# Out:
# 392411

# %%
# 20 avg_price
hotel_data[['avg_saving_percent']].describe()
# Out:
#        avg_saving_percent
# count       392411.000000
# mean             7.238839
# std             13.119062
# min              0.000000
# 25%              0.000000
# 50%              0.000000
# 75%             10.000000
# max             99.000000

# %% [markdown]
# > No negative values here

# %%
hotel_data[hotel_data['avg_saving_percent'].isnull()]
# Out:
# Empty DataFrame
# Columns: [hotel_id, city_id, content_score, n_images, distance_to_center, avg_rating, stars, n_reviews, avg_rank, avg_price, avg_saving_percent, n_clicks]
# Index: []

# %% [markdown]
# > No Nans any more

# %%
# 11 city_id : This is categorical variable. Usually we use one-hot encoding with this type variable. Let's see if it is feasible to apply this strategy here

# %%
city_id_count = hotel_data['city_id'].value_counts().reset_index(name='count').rename(columns={'index': 'city_id'})
city_id_count
# Out:
#         city_id  count
# 0       50168.0   2486
# 1       44470.0   1672
# 2       34798.0   1580
# 3       30576.0   1360
# 4       26874.0   1126
# ...         ...    ...
# 33152  381922.0      1
# 33153  763852.0      1
# 33154  190964.0      1
# 33155  763902.0      1
# 33156       2.0      1
#
# [33157 rows x 2 columns]

# %% [markdown]
# > we have 33,157 unique values for city_id

# %%
city_id_count .hist();

# %% [markdown]
# > We note here that many of these city_ids have low frequency.
#
# - Encoding this categorical variable will result in high dimentional data that was too big to my pc memory. And as we noted above most of these city_id's have low frequency, therefore I am going to replace each cit_id with it's count,i.e how much it appears in the dat set and will then treat it as a numerical variable

# %% [markdown]
# ### Creating new numerical feature for city_id

# %%
# we will merge the original data with the city_id_count from above

# %%
hotel_data = pd.merge(hotel_data,city_id_count ,on=['city_id'], how='left' )
hotel_data
# Out:
#             hotel_id   city_id  content_score  n_images  distance_to_center  \
# 0       9.767406e+10  134520.0           70.0       2.0              1199.0
# 1       9.768889e+10  133876.0           67.0       3.0             12585.0
# 2       9.811544e+10  133732.0           39.0       3.0             23491.0
# 3       9.824279e+10   43772.0           59.0       8.0              3291.0
# 4       9.833438e+10   50532.0           66.0       1.0               288.0
# ...              ...       ...            ...       ...                 ...
# 392406  2.288169e+11  878186.0           48.0       1.0               469.0
# 392407  2.289822e+11   27338.0           42.0       0.0               689.0
# 392408  2.290205e+11   31408.0           70.0       1.0              1424.0
# 392409  2.292421e+11   10718.0           42.0       0.0               164.0
# 392410  2.293708e+11  133338.0           36.0       1.0                 0.0
#
#         avg_rating  stars  n_reviews  avg_rank  avg_price  avg_saving_percent  \
# 0             77.0    4.0      861.0    17.550      81.64                18.0
# 1             90.0    4.0     4371.0    17.383     189.38                28.0
# 2             83.0    3.0     1005.0    16.438      57.63                27.0
# 3             73.0    2.0     3084.0     7.000      72.16                 2.0
# 4             80.0    0.0      603.0    12.564     173.25                 0.0
# ...            ...    ...        ...       ...        ...                 ...
# 392406        83.0    0.0        0.0    21.000      78.86                 0.0
# 392407        83.0    0.0       72.0    14.174     116.56                 4.0
# 392408        83.0    0.0        0.0    16.211      16.11                 0.0
# 392409        84.0    0.0      222.0    20.000     253.81                 0.0
# 392410        83.0    0.0        0.0    20.387      36.13                 0.0
#
#         n_clicks  count
# 0              0     80
# 1              4    751
# 2             44    429
# 3              4      5
# 4             10     73
# ...          ...    ...
# 392406         0     16
# 392407         0     66
# 392408         4     11
# 392409         0      5
# 392410         0     32
#
# [392411 rows x 13 columns]

# %%
# now we can drop the original city_id columns
hotel_data = hotel_data.drop(columns = ['city_id'])

# %%
# Finally let's look at our target variable

# %%
hotel_data[['n_clicks']].describe()
# Out:
#             n_clicks
# count  392411.000000
# mean       13.905808
# std       124.163689
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         2.000000
# max     13742.000000

# %%
# let's check the distribution of n_clicks
hotel_data[['n_clicks']].hist(bins=7);

# %%
hotel_data[['n_clicks']].boxplot();

# %%
# it seems we have a lot of outliers, let's see how many of those is are out side the range between the 5 and 95 quantiles

y = hotel_data['n_clicks']
removed_outliers = y.between(y.quantile(.05), y.quantile(.95))

print(str(y[removed_outliers].size) + "/" + str(len(hotel_data)) + " data points remain.")
# Out:
# 372930/392411 data points remain.

# %%
index_names = hotel_data[~removed_outliers].index

# %%
hotel_data.drop(index_names, inplace=True)

# %%
len(hotel_data)
# Out:
# 372930

# %% [markdown]
# > We will loose around 20,000 rows. let's go ahead and remove those outliers

# %%
### Now let's look at the data type for each column

# %%
hotel_data.dtypes
# Out:
# hotel_id              float64
# content_score         float64
# n_images              float64
# distance_to_center    float64
# avg_rating            float64
# stars                 float64
# n_reviews             float64
# avg_rank              float64
# avg_price             float64
# avg_saving_percent    float64
# n_clicks                int64
# count                   int64
# dtype: object

# %%
# let's convert n_clicks to float as we expect out model to output float numbers for n_clicks

# %%
hotel_data['count'] = hotel_data['count'].astype(float)
hotel_data['n_clicks'] = hotel_data['n_clicks'].astype(float)

# %%
# finally let's saved cleaned data

hotel_data.to_pickle('cleaned.pkl')
